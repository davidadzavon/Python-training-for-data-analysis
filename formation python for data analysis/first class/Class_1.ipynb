# %% [markdown]
# # Welcome to your data analysis course

# %% [markdown]
# Why Python?

# %%
from IPython.display import YouTubeVideo

YouTubeVideo("Y8Tko2YC5hA")

# %% [markdown]
# 1- First program

# %%
print("hello world")

# %% [markdown]
# 2-Data type
#
# we have many type of data type

# %% [markdown]
# 2.1- Numeric data types: int, float, complex
#
# 2.2- String data types: str
#
# 2.3- Sequence types: list, tuple, range
#
# 2.4- Binary types: bytes, bytearray, memoryview
#
# 2.5- Mapping data type: dict
#
# 2.5- Boolean type: bool

# %% [markdown]
# 3-Operator

# %%
from IPython.display import Image
Image("/home/adzavon/Pictures/Screenshots/Screenshot from 2023-01-06 17-55-39.png")

# %%
Image("/home/adzavon/Pictures/Screenshots/Screenshot from 2023-01-06 18-12-25.png")

# %% [markdown]
# 4- Loops

# %%
Image("/home/adzavon/Pictures/Screenshots/Screenshot from 2023-01-06 18-20-54.png")

# %%
Image("/home/adzavon/Pictures/Screenshots/Screenshot from 2023-01-06 18-22-49.png")

# %%
Image("/home/adzavon/Pictures/Screenshots/Screenshot from 2023-01-06 18-24-24.png")

# %%
Image("/home/adzavon/Pictures/Screenshots/Screenshot from 2023-01-06 18-25-26.png")

# %%
Image("/home/adzavon/Pictures/Screenshots/Screenshot from 2023-01-06 18-26-46.png")

# %%
Image("/home/adzavon/Pictures/Screenshots/Screenshot from 2023-01-06 18-28-28.png")
